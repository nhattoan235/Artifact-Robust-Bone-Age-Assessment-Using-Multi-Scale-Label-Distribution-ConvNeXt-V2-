# %%
# !python -c "import torch; print('CUDA:', torch.cuda.is_available()); print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')"

# %%
# !python /kaggle/input/datasets/inhtnphng/baseline-v1/boneage_baseline.py \
  --mode official \
  --data-root /kaggle/input/datasets//boneage_baseline.py \
  --recipe p7_reference \
  --output-root /kaggle/working/outputs \
  --run-name official_gpu \
  --pretrained \
  --img-size 512 \
  --batch-size 4 \
  --workers 2 \
  --epochs 20

# %%
# !python /kaggle/input/datasets/inhtnphng/baseline-v1-2/boneage_baseline.py \
  --mode official \
  --data-root /kaggle/input/datasets/inhtnphng/rsna-bone-age-full-v2 \
  --recipe p7_reference \
  --output-root /kaggle/working/outputs \
  --run-name official_fp16 \
  --pretrained \
  --amp fp16 \
  --img-size 512 \
  --batch-size 2 \
  --workers 2 \
  --epochs 100
